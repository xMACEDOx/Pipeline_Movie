# %% [markdown]
# # Criar SparkSession com suporte ao MinIO

# %%
from pyspark.sql import SparkSession

# Credenciais do MinIO (mesmo valor do seu .env)
MINIO_ENDPOINT  = "http://minio:9000"
MINIO_ACCESS    = "minio"
MINIO_SECRET    = "minio123"

spark = (
    SparkSession.builder
    .appName("moviepulse-bronze-reader")

    # --- JARs necessários para falar com MinIO via protocolo S3 ---
    # hadoop-aws: integração do Hadoop com S3/MinIO
    # aws-java-sdk-bundle: SDK Java da AWS (autenticação, requests)
    # A versão 3.3.4 é compatível com Spark 3.5.x
    .config(
        "spark.jars.packages",
        "org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.262"
    )

    # --- Configurações S3A para apontar para o MinIO ---
    .config("spark.hadoop.fs.s3a.endpoint",               MINIO_ENDPOINT)
    .config("spark.hadoop.fs.s3a.access.key",             MINIO_ACCESS)
    .config("spark.hadoop.fs.s3a.secret.key",             MINIO_SECRET)

    # path.style.access=true é OBRIGATÓRIO para MinIO
    # (MinIO não suporta virtual-hosted style como a AWS real)
    .config("spark.hadoop.fs.s3a.path.style.access",      "true")

    # Implementação S3A do Hadoop
    .config("spark.hadoop.fs.s3a.impl",                   "org.apache.hadoop.fs.s3a.S3AFileSystem")

    # Desabilita SSL (MinIO local não tem certificado)
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false")

    .getOrCreate()
)

# Reduz o volume de logs no notebook
spark.sparkContext.setLogLevel("WARN")

print(f" SparkSession criada! Spark version: {spark.version}")
# Out:
# ✅ SparkSession criada! Spark version: 3.5.0

# %% [markdown]
# # Verificar conectividade com o MinIO
# Lista os arquivos no bucket Bronze antes de ler

# %%
hadoop = spark._jvm.org.apache.hadoop
fs     = hadoop.fs.FileSystem.get(
    spark._jvm.java.net.URI.create("s3a://bronze"),
    spark._jsc.hadoopConfiguration()
)

path = hadoop.fs.Path("s3a://bronze/tmdb/trending_daily/")

try:
    files = fs.listFiles(path, True)  # True = recursivo
    count = 0
    while files.hasNext():
        f = files.next()
        print(f"📄 {f.getPath()} | {f.getLen()} bytes")
        count += 1
    print(f"\n Total de arquivos encontrados: {count}")
except Exception as e:
    print(f" Erro ao acessar o MinIO: {e}")
    print("\n Verifique se:")
    print("   - O container minio está rodando")
    print("   - O bucket 'bronze' existe")
    print("   - As credenciais batem com o seu .env")
# Out:
# 📄 s3a://bronze/tmdb/trending_daily/dt=2025-12-15/events-20251215T041150Z.jsonl | 22721 bytes
# 📄 s3a://bronze/tmdb/trending_daily/dt=2025-12-15/events-20251215T041458Z.jsonl | 22578 bytes
# 📄 s3a://bronze/tmdb/trending_daily/dt=2025-12-15/events-20251215T044051Z.jsonl | 45182 bytes
# 📄 s3a://bronze/tmdb/trending_daily/dt=2026-01-11/events-20260111T011148Z.jsonl | 22377 bytes
# 📄 s3a://bronze/tmdb/trending_daily/dt=2026-01-12/events-20260112T010447Z.jsonl | 22876 bytes
#
# ✅ Total de arquivos encontrados: 5

# %% [markdown]
# # Ler os arquivos JSONL da camada Bronze

# %%
BRONZE_PATH = "s3a://bronze/tmdb/trending_daily/"

df_bronze = (
    spark.read
    .option("recursiveFileLookup", "true")  # lê subpastas dt=YYYY-MM-DD
    .option("multiline", "false")            # JSONL = 1 JSON por linha
    .json(BRONZE_PATH)
)

print(f" DataFrame carregado!")
print(f"   Linhas  : {df_bronze.count()}")
print(f"   Colunas : {len(df_bronze.columns)}")
# Out:
# ✅ DataFrame carregado!
#    Linhas  : 121
#    Colunas : 15

# %% [markdown]
# ## Explorar schema e dados

# %%
# Schema inferido automaticamente pelo Spark
df_bronze.printSchema()
# Out:
# root
#  |-- _kafka: struct (nullable = true)
#  |    |-- key: string (nullable = true)
#  |    |-- offset: long (nullable = true)
#  |    |-- partition: long (nullable = true)
#  |    |-- topic: string (nullable = true)
#  |    |-- ts_ms: long (nullable = true)
#  |-- adult: boolean (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- extraction_ts: string (nullable = true)
#  |-- movie_id: long (nullable = true)
#  |-- original_language: string (nullable = true)
#  |-- popularity: double (nullable = true)
#  |-- raw: struct (nullable = true)
#  |    |-- adult: boolean (nullable = true)
#  |    |-- backdrop_path: string (nullable = true)
#  |    |-- genre_ids: array (nullable = true)
#  |    |    |-- element: long (containsNull = true)
#  |    |-- id: long (nullable = true)
#  |    |-- media_type: string (nullable = true)
#  |    |-- original_language: string (nullable = true)
#  |    |-- original_title: string (nullable = true)
#  |    |-- overview: string (nullable = true)
#  |    |-- popularity: double (nullable = true)
#  |    |-- poster_path: string (nullable = true)
#  |    |-- release_date: string (nullable = true)
#  |    |-- title: string (nullable = true)
#  |    |-- video: boolean (nullable = true)
#  |    |-- vote_average: double (nullable = true)
#  |    |-- vote_count: long (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- source: string (nullable = true)
#  |-- source_date: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- vote_average: double (nullable = true)
#  |-- vote_count: long (nullable = true)

# %%
# Primeiras linhas com as colunas principais
df_bronze.select(
    "movie_id",
    "title",
    "source_date",
    "popularity",
    "vote_average",
    "vote_count",
    "original_language"
).show(20, truncate=False)
# Out:
# +--------+-------------------------------------+-----------+----------+------------+----------+-----------------+
# |movie_id|title                                |source_date|popularity|vote_average|vote_count|original_language|
# +--------+-------------------------------------+-----------+----------+------------+----------+-----------------+
# |812583  |Vivo ou Morto: Um Mistério Knives Out|2025-12-15 |368.6188  |7.408       |482       |en               |
# |812583  |Vivo ou Morto: Um Mistério Knives Out|2025-12-15 |368.6188  |7.408       |482       |en               |
# |798645  |O Sobrevivente                       |2025-12-15 |429.9601  |6.776       |473       |en               |
# |798645  |O Sobrevivente                       |2025-12-15 |429.9601  |6.776       |473       |en               |
# |1084242 |Zootopia 2                           |2025-12-15 |431.2602  |7.669       |588       |en               |
# |1084242 |Zootopia 2                           |2025-12-15 |431.2602  |7.669       |588       |en               |
# |1401778 |Turbulence                           |2025-12-15 |27.911    |6.9         |7         |en               |
# |1401778 |Turbulence                           |2025-12-15 |27.911    |6.9         |7         |en               |
# |83533   |Avatar: Fogo e Cinzas                |2025-12-15 |121.0001  |0.0         |0         |en               |
# |83533   |Avatar: Fogo e Cinzas                |2025-12-15 |121.0001  |0.0         |0         |en               |
# |1218925 |Chainsaw Man – O Filme: Arco da Reze |2025-12-15 |210.4862  |8.276       |391       |ja               |
# |1218925 |Chainsaw Man – O Filme: Arco da Reze |2025-12-15 |210.4862  |8.276       |391       |ja               |
# |533533  |Tron: Ares                           |2025-12-15 |253.831   |6.554       |730       |en               |
# |533533  |Tron: Ares                           |2025-12-15 |253.831   |6.554       |730       |en               |
# |1228246 |Five Nights at Freddy's 2            |2025-12-15 |242.7947  |6.371       |171       |en               |
# |1228246 |Five Nights at Freddy's 2            |2025-12-15 |242.7947  |6.371       |171       |en               |
# |701387  |Bugonia                              |2025-12-15 |57.8758   |7.438       |791       |en               |
# |701387  |Bugonia                              |2025-12-15 |57.8758   |7.438       |791       |en               |
# |1242898 |Predador: Terras Selvagens           |2025-12-15 |163.7653  |7.344       |635       |en               |
# |1242898 |Predador: Terras Selvagens           |2025-12-15 |163.7653  |7.344       |635       |en               |
# +--------+-------------------------------------+-----------+----------+------------+----------+-----------------+
# only showing top 20 rows

# %%
# Estatísticas descritivas das métricas numéricas
df_bronze.select("popularity", "vote_average", "vote_count").describe().show()
# Out:
# +-------+------------------+-----------------+------------------+
# |summary|        popularity|     vote_average|        vote_count|
# +-------+------------------+-----------------+------------------+
# |  count|               120|              120|               120|
# |   mean|        151.303715|6.809258333333331|1287.3916666666667|
# | stddev|147.91603799730422|1.438985896975602| 3218.911691171447|
# |    min|            7.0898|              0.0|                 0|
# |    max|          816.4153|            8.282|             33220|
# +-------+------------------+-----------------+------------------+

# %%
# Registros por data de coleta — confirma que o pipeline está rodando
df_bronze.groupBy("source_date").count().orderBy("source_date").show()
# Out:
# +-----------+-----+
# |source_date|count|
# +-----------+-----+
# |       NULL|    1|
# | 2025-12-15|   80|
# | 2026-01-11|   20|
# | 2026-01-12|   20|
# +-----------+-----+

# %% [markdown]
# # Checar qualidade dos dados (nulos)
# Boa prática antes de avançar para a camada Silver.

# %%
from pyspark.sql import functions as F

cols_to_check = ["movie_id", "title", "source_date", "popularity", "vote_average", "vote_count", "release_date"]

null_counts = df_bronze.select([
    F.count(F.when(F.col(c).isNull(), c)).alias(c)
    for c in cols_to_check
])

print("📊 Contagem de nulos por coluna:")
null_counts.show()
# Out:
# 📊 Contagem de nulos por coluna:
# +--------+-----+-----------+----------+------------+----------+------------+
# |movie_id|title|source_date|popularity|vote_average|vote_count|release_date|
# +--------+-----+-----------+----------+------------+----------+------------+
# |       1|    1|          1|         1|           1|         1|           1|
# +--------+-----+-----------+----------+------------+----------+------------+
